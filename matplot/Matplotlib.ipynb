# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); # to get rid of square brackets in above output

# %%
plt.plot()
plt.show() # also udes to get rid of square brackets

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
# pyplot API is generally less flexible than object-oriented API

# %%
#1st method
fig =plt.figure() #creates a figure
ax=fig.add_subplot()#adds some axes
fig.show()
# Out:
# /tmp/ipykernel_6139/425480661.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#2nd method
fig =plt.figure() # creates figure
ax=fig.add_axes([1,1,1,1]) # here [1,1,1,1] is rect ==>[left,bottom,width,height]
ax.plot(x,y) #add some data
plt.show()

# %% [markdown]
# <img src = "../matplot/figure.add_axes[l,b,w,h].png" width =600/>

# %%
# 3rd method (recommended)
fig,ax=plt.subplots()
ax.plot(x,y) #add some data

# %%
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250]) #add some data
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# <img src="matplotlib-anatomy-of-a-plot.png" width = 600/>

# %% [markdown]
# #### Matplotlib Example workflow

# %%
#0. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data
x=[1,2,3,4]
y=[11,22,33,44]

# 2. Setup plot
fig, ax =plt.subplots(figsize=(5 ,10))

# 3.PLot data
ax.plot(x,y)

# 4.customize plt
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel =  "y-axis")

#5. Save & show (you savethe whole figure)
fig.savefig("../matplot/sample-plot.png")

# %% [markdown]
# ### Making figure with Numpy array
# * Line Plot
# * Scatter Plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
# create some data
x=np.linspace(0,10,100)# returns 100 evenly splaced numbeers from 0 to 10
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ###### 1.Line PLot

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# ###### 2.Scatter plot

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x));

# %% [markdown]
# ###### 3.Bar graph

# %%
#Make a plot from dictionary
nut_prices = {'Almond butter':10,
             'Peanut butter': 8,
             'cashew butter' :12}
fig,ax=plt.subplots()

ax.bar(nut_prices.keys(),nut_prices.values())# Here y is replaced by height
ax.set(title="Nut store",ylabel="Price($)");
# put semicolon on the last line where u acces to get rid of square brackets above the graph

# %% [markdown]
# * fig,ax=plt.subplots()
#
# * ax.bar( x=nut_prices.keys() ,   height = nut_prices.values() )
#         * SyntaxError: positional argument follows keyword argument
#
# * ax.bar (nut_prices.keys() ,     height=nut_prices.values() )
#         *but above satement will give output
#
# * this is due to python syntax that positional argument (x=) can not come first but it can come after first argument

# %% [markdown]
# ###### ==>Horizontal bar graph

# %%
#fig,ax=plt.subplots()
#ax.barh(nut_prices.keys(),nut_prices.values())
        #TypeError: unhashable type: 'dict_keys'

# %%
fig,ax=plt.subplots()
ax.barh(  list(nut_prices.keys()) , list(nut_prices.values())  );

# %% [markdown]
# ###### 4.Histogram

# %%
x=np.random.randn(1000) #Return a sample from the "standard normal" distribution.
fig,ax = plt.subplots()
ax.hist(x);             # this kind of graph which has peak in between is called standard normal distributiom

# %% [markdown]
# ## Two options for sublots

# %% [markdown]
# **a) subplot option 1**

# %%
fig,((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows = 2,ncols=2 , figsize=(10,5))

# %%
x=np.random.randn(1000)

# %%
fig,((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows = 2,ncols=2 , figsize=(10,5))

#plot to each different axis

ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_prices.keys(), nut_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# **b) subplot option 2**

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
# PLot to each index

ax[0,0].plot(x,x/2); # Row zero & Column Zero
ax[0,1].scatter(np.random.random(10) , np.random.random(10)); # Row 0 & Column 1
ax[1,0].bar(nut_prices.keys(), nut_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting data from pandas as DataFrames

# %%
import pandas as pd

# %%
ts = pd.Series(np.random.randn(1000),
                  index=pd.date_range('1/1/2000', periods =1000))
ts,ts.plot()
# Out:
# (2000-01-01   -0.971817
#  2000-01-02   -0.676888
#  2000-01-03   -0.151996
#  2000-01-04   -0.419321
#  2000-01-05   -0.668851
#                  ...
#  2002-09-22    0.134503
#  2002-09-23   -0.562575
#  2002-09-24   -0.009481
#  2002-09-25    0.796768
#  2002-09-26    0.242420
#  Freq: D, Length: 1000, dtype: float64,
#  <AxesSubplot:>)

# %%
ap = ts.cumsum()
ap.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales= pd.read_csv("../pandas/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\.\,]','')
car_sales
# Out:
# /tmp/ipykernel_6139/4290654481.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\.\,]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"]), type(car_sales["Price"][0])
# Out:
# (pandas.core.series.Series, str)

# %%
#Remove last 2 zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
#Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)" , y="Price", kind="scatter");

# %%
# bar graph
x  = np.random.rand(10,4)
x

# Turn it into a dataframe
df = pd.DataFrame(x,columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.835863  0.261401  0.354043  0.484701
# 1  0.534255  0.414403  0.317841  0.531154
# 2  0.566972  0.994439  0.819181  0.874706
# 3  0.644839  0.236191  0.386126  0.958398
# 4  0.321940  0.495836  0.034687  0.895234
# 5  0.209898  0.929865  0.723278  0.113048
# 6  0.642575  0.472767  0.430340  0.002618
# 7  0.556717  0.488317  0.544617  0.548227
# 8  0.125240  0.624382  0.105553  0.186724
# 9  0.559121  0.873542  0.456043  0.601099

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make" , y="Odometer (KM)", kind = "bar");

# %%
#Histograms - better to understand distributions
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins = 40);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease.plot.hist(figsize = (10,30),subplots = True);

# %% [markdown]
# The problem in the above statement is that it is using the same scale for all the column

# %% [markdown]
# #### Should we use the pyplot method or matplotlib OO method
# * For plotting quickly, use the pyplot method
# * When plotting smtg advanced , use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] >50]
len(over_50)
# Out:
# 208

# %%
# Pyplot method(plotting directly from the pandas DataFrame)
over_50.plot(kind="scatter",x='age' , y ='chol' , c = 'target',figsize=(10,6));
# c-colour

# %%
##OO method
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot( kind ='scatter',x='age',y='chol',c='target',ax=ax);

# %% [markdown]
# we added ax=ax in the oo method, and we can see the axis label in this method

# %%
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot( kind ='scatter',x='age',y='chol',c='target',ax=ax);
ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %% [markdown]
# sets the limit of x-axis

# %%
####OO method from the scratch

fig,ax = plt.subplots(figsize = (10,6))

#Plot the data
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],
                     c=over_50["target"]);

#customize
ax.set(title = "Heart Disease and Cholesterol Levels",
      xlabel = "Age",ylabel = "Cholesterol");
#Add a legend
ax.legend(*scatter.legend_elements() , title = "Target");

#Adding a horizontal line in the plot
ax.axhline(over_50["chol"].mean(), linestyle='--');

# %%
 over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot fo chol , age , thalach
fig, (ax0,ax1) = plt.subplots(nrows = 2, ncols = 1,
                              figsize=(10,10))

#Add data to ax0
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],
                     c=over_50["target"])

#Customize ax0
ax0.set(title="Heart Disease and CHolestrol Levels",
       xlabel="Age",ylabel = "Cholesterol");
#Add a legend
ax0.legend(*scatter.legend_elements(), title ="Target")

#Add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle ='--');


#Add data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],
                      c=over_50["target"])

#Customize ax1
ax1.set(title="Heart Disease and Thalach Levels",
       xlabel="Age",ylabel = "thalach");
#Add a legend
ax1.legend(*scatter.legend_elements(), title ="Target")

#Add a mean line
ax1.axhline(y=over_50["thalach"].mean(), linestyle ='--');

# Add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %%
## Sharing the xaxis and removing the xaxis label for ax0


# Subplot fo chol , age , thalach
fig, (ax0,ax1) = plt.subplots(nrows = 2, ncols = 1,
                              figsize=(10,10),
                             sharex=True)

#Add data to ax0
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],
                     c=over_50["target"])

#Customize ax0
ax0.set(title="Heart Disease and CHolestrol Levels",
       ylabel = "Cholesterol");
#Add a legend
ax0.legend(*scatter.legend_elements(), title ="Target")

#Add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle ='--');


#Add data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],
                      c=over_50["target"])

#Customize ax1
ax1.set(title="Heart Disease and Thalach Levels",
       xlabel="Age",ylabel = "thalach");
#Add a legend
ax1.legend(*scatter.legend_elements(), title ="Target")

#Add a mean line
ax1.axhline(y=over_50["thalach"].mean(), linestyle ='--');

# %% [markdown]
# ## Customizing Matplotlib plots and getting Styles

# %%
#see the diff styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
x = np.random .randn(10,4)
df = pd.DataFrame(x,columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -1.419249  1.013663 -0.965599  0.930802
# 1  0.510024  0.774989 -1.397582 -1.111413
# 2 -0.117321  0.940744 -1.029204  0.936392
# 3 -1.222162  0.994023  0.656658  1.152201
# 4  1.172436 -0.521424  1.750801 -1.572329
# 5  0.050693  2.051809  0.436176  2.126118
# 6  0.268821  0.110751 -0.351046  1.717856
# 7  1.084010  0.342887 -0.180283  0.377185
# 8 -0.075751 -0.550454  0.324983  0.702246
# 9 -0.204484  2.310653 -0.559516  0.169962

# %%
ax =df.plot(kind ='bar');
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
#Customize our plot with the set() method
ax = df.plot(kind="bar")

#Add some labels and a title
ax.set(title = "Random Number Bar Graph from DataFrame",
      xlabel = "Row number",
      ylabel = "Random number")
#Make the legend visible 
ax.legend().set_visible(True)

# %% [markdown]
# ### changing the style within the style

# %%
fig,ax = plt.subplots(figsize = (10,6))

#Plot the data
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],
                     c=over_50["target"]);

#customize
ax.set(title = "Heart Disease and Cholesterol Levels",
      xlabel = "Age",ylabel = "Cholesterol");
#Add a legend
ax.legend(*scatter.legend_elements() , title = "Target");

#Adding a horizontal line in the plot
ax.axhline(over_50["chol"].mean(), linestyle='--');

# %%
fig,ax = plt.subplots(figsize = (10,6))

#Plot the data
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],
                     c=over_50["target"],
                    cmap = "winter");# it changes the colour scheme(summer,winter,plasma)

#customize
ax.set(title = "Heart Disease and Cholesterol Levels",
      xlabel = "Age",ylabel = "Cholesterol");
#Add a legend
ax.legend(*scatter.legend_elements() , title = "Target");

#Adding a horizontal line in the plot
ax.axhline(over_50["chol"].mean(), linestyle='--');

# %% [markdown]
# ##### Customizing the x and y axis limitations

# %%
## Sharing the xaxis and removing the xaxis label for ax0


# Subplot fo chol , age , thalach
fig, (ax0,ax1) = plt.subplots(nrows = 2, ncols = 1,
                              figsize=(10,10),
                             sharex=True)

#Add data to ax0
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],
                     c=over_50["target"],
                     cmap ="winter")

#Customize ax0
ax0.set(title="Heart Disease and CHolestrol Levels",
       ylabel = "Cholesterol");

#Change the xaxis limits
ax0.set_xlim([50,80])#comment and uncomment this line to see the change
                     #comment the ax1.set_xlim line also to see the change


#Add a legend
ax0.legend(*scatter.legend_elements(), title ="Target")

#Add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle ='--');




#Add data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],
                      c=over_50["target"],
                     cmap ="winter")

#Customize ax1
ax1.set(title="Heart Disease and Thalach Levels",
       xlabel="Age",ylabel = "thalach");

ax1.set_xlim([50,80]) 
ax1.set_ylim([60,200])

#Add a legend
ax1.legend(*scatter.legend_elements(), title ="Target")

#Add a mean line
ax1.axhline(y=over_50["thalach"].mean(), linestyle ='--');

# %% [markdown]
# #### Saving the plots

# %% [markdown]
#  1.Right click on the plot and click on save image as

# %%
fig.savefig("heart-disease-analysis-plot.png")
