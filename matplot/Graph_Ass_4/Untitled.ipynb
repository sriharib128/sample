# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
a=pd.read_csv("./q1_tdp-Copy1.csv")
fig, ax = plt.subplots(1,figsize=(15,6))

fig.set(facecolor = "white")

a.plot( kind ='line',x=' width  ',y=' delay ',ax=ax);
ax.set_title('Varying MN1 width')
ax.set_xlabel("width in nm")
ax.set_ylabel("time_delay")
fig.savefig("./q4_a_mp1.png")

# %%
a
# Out:
#       temp         width
# 0     0.16  1.810730e-11
# 1     0.32  1.810930e-11
# 2     0.48  1.811130e-11
# 3     0.64  1.811330e-11
# 4     0.80  1.811520e-11
# ..     ...           ...
# 495  79.36  1.882090e-11
# 496  79.52  1.882190e-11
# 497  79.68  1.882280e-11
# 498  79.84  1.882370e-11
# 499  80.00  1.882470e-11
#
# [500 rows x 2 columns]
