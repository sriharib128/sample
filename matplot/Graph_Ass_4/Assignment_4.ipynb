# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
a=pd.read_csv("./1_1.csv")

fig, (ax,ax1) = plt.subplots(1,2,figsize=(15,6))

ax.set(ylim=[166000,167100])
a.plot( kind ='bar',x='no',y='frequency',ax=ax,width=0.98);

ax1.set(ylim=[166000,167100])
a.plot( kind ='bar',x='no',y='mean',ax=ax1,width=0.98);

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

df = pd.DataFrame(dict(data=[2, 4, 1, 5, 9, 6, 0, 7]))
fig, ax = plt.subplots()

df['data'].plot(kind='bar', color='red')
df['data'].plot(kind='line', marker='*', color='black', ms=10)

plt.show()

# %%
a=pd.read_csv("./1_2.csv")

fig, (ax,ax1) = plt.subplots(1,2,figsize=(15,6))

# ax.set(ylim=[166000,167100])
a.plot( kind ='bar',x='no',y='freq',ax=ax,width=0.98);

# ax1.set(ylim=[166000,167100])
a.plot( kind ='bar',x='no',y='mean',ax=ax1,width=0.98);

# %%
fig, (ax,ax1) = plt.subplots(1,2,figsize=(15,6))

# ax.set(ylim=[166000,167100])
a.plot( kind ='bar',x,y='freq',ax=ax);

# %%
#0. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data
x=[1,2,3,4]
i=3
y=[0,0,0,0]
while(i>=0):
    y[i]=x[i]**2
    print(y[i]);
    i=i-1;
    

# 2. Setup plot
fig, ax =plt.subplots(figsize=(5 ,10))

# 3.PLot data
ax.plot(x,y)

# 4.customize plt
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel = "y-axis")

#5. Save & show (you savethe whole figure)
fig.savefig("./sample-plot.png")
# Out:
# 16
# 9
# 4
# 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# create 1000 equally spaced points between -10 and 10
x = np.linspace(-10, 10, 1000)

# calculate the y value for each element of the x vector
y = x**2 + 2*x + 2  

fig, ax = plt.subplots()
ax.plot(x, y)

# %%
fig, ax = plt.subplots(1,figsize=(5,6))
x = np.linspace(-10, 10, 1000)
y  = 24 - 19.2*(math.e**(-5*x)) 
ax.set(xlim=[-0.01,2])
ax.set(ylim=[0,28])
ax.set(title="I vs T",
       xlabel="t (seconds) \u2192",
       ylabel = "I (mA) \u2192")
ax.plot(x,y,color="black");
fig.savefig("./sample-plot.png")

# %%
print("I\u2081\u2080\u2080 (mA) \u2192")
# Out:
# I₁₀₀ (mA) →
